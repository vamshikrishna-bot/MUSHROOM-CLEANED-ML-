# %%
import pandas as pd
import numpy as np
d=pd.read_csv('/content/mushroom_cleaned.csv')
print(d)
# Out:
#        cap-diameter  cap-shape  gill-attachment  gill-color  stem-height  \
# 0              1372          2                2          10     3.807467
# 1              1461          2                2          10     3.807467
# 2              1371          2                2          10     3.612496
# 3              1261          6                2          10     3.787572
# 4              1305          6                2          10     3.711971
# ...             ...        ...              ...         ...          ...
# 54030            73          5                3           2     0.887740
# 54031            82          2                3           2     1.186164
# 54032            82          5                3           2     0.915593
# 54033            79          2                3           2     1.034963
# 54034            72          5                3           2     1.158311
#
#        stem-width  stem-color    season  class
# 0            1545          11  1.804273      1
# 1            1557          11  1.804273      1
# 2            1566          11  1.804273      1
# 3            1566          11  1.804273      1
# 4            1464          11  0.943195      1
# ...           ...         ...       ...    ...
# 54030         569          12  0.943195      1
# 54031         490          12  0.943195      1
# 54032         584          12  0.888450      1
# 54033         491          12  0.888450      1
# 54034         492          12  0.888450      1
#
# [54035 rows x 9 columns]

# %%
y=d['class']
print(y)
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 54030    1
# 54031    1
# 54032    1
# 54033    1
# 54034    1
# Name: class, Length: 54035, dtype: int64

# %%
x=d.drop(['class','cap-diameter'],axis=1)
print(x)
# Out:
#        cap-shape  gill-attachment  gill-color  stem-height  stem-width  \
# 0              2                2          10     3.807467        1545
# 1              2                2          10     3.807467        1557
# 2              2                2          10     3.612496        1566
# 3              6                2          10     3.787572        1566
# 4              6                2          10     3.711971        1464
# ...          ...              ...         ...          ...         ...
# 54030          5                3           2     0.887740         569
# 54031          2                3           2     1.186164         490
# 54032          5                3           2     0.915593         584
# 54033          2                3           2     1.034963         491
# 54034          5                3           2     1.158311         492
#
#        stem-color    season
# 0              11  1.804273
# 1              11  1.804273
# 2              11  1.804273
# 3              11  1.804273
# 4              11  0.943195
# ...           ...       ...
# 54030          12  0.943195
# 54031          12  0.943195
# 54032          12  0.888450
# 54033          12  0.888450
# 54034          12  0.888450
#
# [54035 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
matrix = np.triu(d.corr())
sns.heatmap(d.corr(), mask=matrix, cmap='vlag',
            linewidths=0.5, linecolor='white',annot=True, annot_kws={'size':5})
plt.show()

# %%
import seaborn as sns
sns.pairplot(x)

# %%
import matplotlib.pyplot as plt

plt.scatter(d['cap-shape'],d['class'])
plt.xlabel("cap-shape")
plt.ylabel("class")
plt.show()


plt.scatter(d['gill-attachment'],d['class'])
plt.xlabel("gill-attachment")
plt.ylabel("class")
plt.show()


plt.scatter(d['gill-color'],d['class'])
plt.xlabel("gill-color")
plt.ylabel("class")
plt.show()




plt.scatter(d['stem-height'],d['class'])
plt.xlabel("stem-height")
plt.ylabel("class")
plt.show()


plt.scatter(d['stem-width'],d['class'])
plt.xlabel("stem-width")
plt.ylabel("class")
plt.show()

plt.scatter(d['stem-color'],d['class'])
plt.xlabel("stem-color")
plt.ylabel("class")
plt.show()

plt.scatter(d['season'],d['class'])
plt.xlabel("season")
plt.ylabel("class")
plt.show()

# %%
x.isnull().sum()
x.replace([np.inf, -np.inf], np.nan, inplace=True)
x.fillna(0, inplace=True)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import  Perceptron
model_per=Perceptron()
model_per.fit(x_train,y_train)
# Out:
# Perceptron()

# %%
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
model=Perceptron()
model.fit(x_train,y_train)
y_pred1=model.predict(x_test)

accuracy=accuracy_score(y_test,y_pred1)
confusion=confusion_matrix(y_test,y_pred1)
report=classification_report(y_test,y_pred1)

print("Classification Report:")
print(report)
print()
print()
print("Confusion Matrix:")
print(confusion)
print()
print()
print("Accuracy:",accuracy)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.46      0.99      0.63      4834
#            1       0.87      0.05      0.10      5973
#
#     accuracy                           0.47     10807
#    macro avg       0.67      0.52      0.36     10807
# weighted avg       0.69      0.47      0.34     10807
#
#
#
# Confusion Matrix:
# [[4788   46]
#  [5652  321]]
#
#
# Accuracy: 0.47274914407328583

# %%
from sklearn.linear_model import LogisticRegression
model_Logistic = LogisticRegression(max_iter=1000)
model_Logistic.fit(x, y)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
y_pred2=model.predict(x_test)

accuracy=accuracy_score(y_test,y_pred2)
confusion=confusion_matrix(y_test,y_pred2)
report=classification_report(y_test,y_pred2)

print("Classification Report:")
print(report)
print()
print()
print("Confusion Matrix:")
print(confusion)
print()
print()
print("Accuracy:",accuracy)
print()
print()
print()
print()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.53      0.56      4834
#            1       0.65      0.71      0.68      5973
#
#     accuracy                           0.63     10807
#    macro avg       0.62      0.62      0.62     10807
# weighted avg       0.63      0.63      0.63     10807
#
#
#
# Confusion Matrix:
# [[2571 2263]
#  [1731 4242]]
#
#
# Accuracy: 0.6304247247154622
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.svm import SVC
model_svc = SVC()
model_svc.fit(x_train, y_train)
# Out:
# SVC()

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(x_train,y_train)
y_pred3=model.predict(x_test)

accuracy=accuracy_score(y_test,y_pred3)
confusion=confusion_matrix(y_test,y_pred3)
report=classification_report(y_test,y_pred3)

print("Classification Report:")
print(report)
print()
print()
print("Confusion Matrix:")
print(confusion)
print(  )
print("Accuracy:",accuracy)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.57      0.57      4928
#            1       0.64      0.66      0.65      5879
#
#     accuracy                           0.62     10807
#    macro avg       0.61      0.61      0.61     10807
# weighted avg       0.62      0.62      0.62     10807
#
#
#
# Confusion Matrix:
# [[2794 2134]
#  [2019 3860]]
#
# Accuracy: 0.615712038493569

# %%
from sklearn.neighbors import KNeighborsClassifier
model_knn = KNeighborsClassifier(n_neighbors=5)
model_knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()
model.fit(x_train,y_train)
y_pred4 = model.predict(x_test)

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

accuracy = accuracy_score(y_test, y_pred4)
print("Accuracy:", accuracy)
print()
confusion = confusion_matrix(y_test, y_pred4)
print("Confusion Matrix:")
print(confusion)
print()
report = classification_report(y_test, y_pred4)
print("Classification Report:")
print(report)
# Out:
# Accuracy: 0.8341815489960211
#
# Confusion Matrix:
# [[4115  813]
#  [ 979 4900]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82      4928
#            1       0.86      0.83      0.85      5879
#
#     accuracy                           0.83     10807
#    macro avg       0.83      0.83      0.83     10807
# weighted avg       0.83      0.83      0.83     10807

# %%
from sklearn.utils import resample
x.shape
print(x.shape)
y.shape
print(y.shape)
# Out:
# (54035, 7)
# (54035,)

# %%
knn_accuracies = []
lr=[]
sv=[]

# %%
model_Logistic = LogisticRegression(max_iter=1000)
model_knn = KNeighborsClassifier()
Model_svc=SVC()

# %%
for i in range(10):
    x_resample,y_resample=resample(x,y)
    x_train, x_test, y_train, y_test = train_test_split(x_resample,y_resample, test_size=0.2,random_state=42)

    model_Logistic.fit(x_train, y_train)
    model_knn.fit(x_train, y_train)
    Model_svc.fit(x_train, y_train)



    y_pred_lr = model_Logistic.predict(x_test)
    y_pred_knn = model_knn.predict(x_test)
    y_pred_svc=Model_svc.predict(x_test)

    accuracy_knn = accuracy_score(y_test, y_pred_knn)
    accuracy_lr = accuracy_score(y_test, y_pred_lr)
    accuracy_svc=accuracy_score(y_test,y_pred_svc)

    knn_accuracies.append(accuracy_knn)
    lr.append(accuracy_lr)
    sv.append(accuracy_svc)

# %%
knn_accuracies
# Out:
# [0.8586101600814287,
#  0.8608309429073748,
#  0.8636994540575553,
#  0.8583325622281854,
#  0.8582400296104377,
#  0.8548163227537707,
#  0.8638845192930508,
#  0.8636994540575553,
#  0.8609234755251226,
#  0.8631442583510688,
#  0.8591653557879152,
#  0.8618488017026001,
#  0.8629591931155732,
#  0.859628018876654,
#  0.8544461922827796,
#  0.8563893772554826,
#  0.8587952253169242,
#  0.863051725733321,
#  0.8581474969926899,
#  0.8562968446377348]

# %%
lr
# Out:
# [0.6292218006847413,
#  0.6386601276950125,
#  0.6366244101045618,
#  0.6324604423059128,
#  0.6261682242990654,
#  0.6246877024151013,
#  0.6395854538724901,
#  0.6327380401591561,
#  0.6387526603127602,
#  0.6411585083742019,
#  0.6401406495789765,
#  0.6270010178587953,
#  0.646062737114833,
#  0.6318127139816785,
#  0.6378273341352827,
#  0.630887387804201,
#  0.6353289534560933,
#  0.6342185620431202,
#  0.6332007032478949,
#  0.6349588229851022]

# %%
sv
# Out:
# [0.61154807069492,
#  0.6159896363468123,
#  0.6249653002683446,
#  0.611918201165911,
#  0.6158971037290645,
#  0.6205237346164523,
#  0.6159896363468123,
#  0.6192282779679837,
#  0.6311649856574443,
#  0.6199685389099657]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 10)

min_len = min(len(x), len(lr), len(knn_accuracies))
x = x[:min_len]

lr = lr[:min_len]
knn_accuracies = knn_accuracies[:min_len]
sv=sv[:min_len]

plt.figure(figsize=(10, 6))

plt.title('Boostrap')

plt.plot(x, knn_accuracies, marker='^', label='knn', color='blue')

plt.plot(x, lr, marker='o', label='lr', color='green')

plt.plot(x, sv, marker='s', label='sv', color='red')

plt.show()

# %%
# !pip install pyswarm
# Out:
# Collecting pyswarm
#   Downloading pyswarm-0.6.tar.gz (4.3 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyswarm) (1.26.4)
# Building wheels for collected packages: pyswarm
#   Building wheel for pyswarm (setup.py) ... done
#   Created wheel for pyswarm: filename=pyswarm-0.6-py3-none-any.whl size=4464 sha256=d97b42e2abfe2abd9b90eda0914c721dacebea7d372424672b291eccb11df6f8
#   Stored in directory: /root/.cache/pip/wheels/71/67/40/62fa158f497f942277cbab8199b05cb61c571ab324e67ad0d6
# Successfully built pyswarm
# Installing collected packages: pyswarm
# Successfully installed pyswarm-0.6

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from pyswarm import pso
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in d.columns:
    d[col] = le.fit_transform(d[col])

X = d.drop('class', axis=1)
y = d['class']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

def objective_function(params):
    n_estimators, max_depth = int(params[0]), int(params[1])
    model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=42)
    model.fit(X_train, y_train)
    score = model.score(X_test, y_test)
    return 1 - score

lb = [10, 5]
ub = [200, 20]


best_params, _ = pso(objective_function, lb, ub, swarmsize=10, maxiter=10)

best_n_estimators, best_max_depth = int(best_params[0]), int(best_params[1])


best_model = RandomForestClassifier(n_estimators=best_n_estimators, max_depth=best_max_depth, random_state=42)
best_model.fit(X_train, y_train)


y_pred = best_model.predict(X_test)
report = classification_report(y_test, y_pred, output_dict=True)


print("Classification Report:")
print(classification_report(y_test, y_pred))


report_df = pd.DataFrame(report).transpose()


plt.figure(figsize=(8, 6))
report_df['support'][:-3].plot(kind='bar')
plt.title('PSO Optimized RandomForest - Mushroom Dataset')
plt.xlabel('Class')
plt.ylabel('Support')
plt.show()
# Out:
# Stopping search: maximum iterations reached --> 10
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7349
#            1       0.99      0.99      0.99      8862
#
#     accuracy                           0.99     16211
#    macro avg       0.99      0.99      0.99     16211
# weighted avg       0.99      0.99      0.99     16211
